# %%
# Import Dependencies
import pandas as pd

# %%
crime_data_csv = "../Carl's Stuff/CrimeData.csv"

# %%
crime_data_df = pd.read_csv(crime_data_csv)

# %%
crime_data_df.head()
# Out:
#    Unnamed: 0        id case_number                     date  \
# 0           0  12196867    JD403511  2020-10-18T12:00:00.000
# 1           1  12190352    JD395873  2020-10-10T18:28:00.000
# 2           2  12195981    JD402514  2020-10-17T15:15:00.000
# 3           3  12194134    JD400316  2020-10-15T14:00:00.000
# 4           4  12195268    JD400951  2020-10-15T13:56:00.000
#
#                   block  iucr primary_type  \
# 0  008XX N MICHIGAN AVE  0860        THEFT
# 1  008XX N MICHIGAN AVE  0312      ROBBERY
# 2  008XX N MICHIGAN AVE  0870        THEFT
# 3  008XX N MICHIGAN AVE  0860        THEFT
# 4  008XX N MICHIGAN AVE  0860        THEFT
#
#                           description location_description  arrest  ...  ward  \
# 0                        RETAIL THEFT     DEPARTMENT STORE   False  ...     2
# 1  ARMED - KNIFE / CUTTING INSTRUMENT   SMALL RETAIL STORE   False  ...    42
# 2                      POCKET-PICKING           RESTAURANT   False  ...     2
# 3                        RETAIL THEFT   SMALL RETAIL STORE   False  ...     2
# 4                        RETAIL THEFT     DEPARTMENT STORE   False  ...     2
#
#    community_area  fbi_code  year               updated_on x_coordinate  \
# 0               8        06  2020  2020-10-25T15:52:01.000          NaN
# 1               8        03  2020  2020-10-25T15:49:20.000    1177338.0
# 2               8        06  2020  2020-10-24T15:51:49.000          NaN
# 3               8        06  2020  2020-10-22T15:48:01.000          NaN
# 4               8        06  2020  2020-10-22T15:48:01.000          NaN
#
#    y_coordinate   latitude  longitude  \
# 0           NaN        NaN        NaN
# 1     1906160.0  41.897838 -87.624097
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
#
#                                             location
# 0                                                NaN
# 1  {'latitude': '41.897837503', 'longitude': '-87...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
len(crime_data_df)
# Out:
# 9082

# %%
crime_2020_df = crime_data_df[crime_data_df["year"]==2020]
crime_2019_df = crime_data_df[crime_data_df["year"]==2019]
crime_2018_df = crime_data_df[crime_data_df["year"]==2018]
crime_2017_df = crime_data_df[crime_data_df["year"]==2017]
crime_2016_df = crime_data_df[crime_data_df["year"]==2016]
crime_2015_df = crime_data_df[crime_data_df["year"]==2015]
crime_2014_df = crime_data_df[crime_data_df["year"]==2014]
crime_2013_df = crime_data_df[crime_data_df["year"]==2013]
crime_2012_df = crime_data_df[crime_data_df["year"]==2012]
crime_2011_df = crime_data_df[crime_data_df["year"]==2011]

# %%
crime_remainder_df = crime_data_df[crime_data_df["year"]<=2002]

# %%
crime_2019_df
# Out:
#       Unnamed: 0        id case_number                     date  \
# 59            59  12126659    JD321696  2019-12-24T12:00:00.000
# 162          162  11930492    JC558006  2019-12-23T16:30:00.000
# 163          163  11929535    JC556492  2019-12-22T12:53:00.000
# 164          164  11928464    JC555470  2019-12-21T13:38:00.000
# 165          165  11928253    JC555069  2019-12-20T16:30:00.000
# ...          ...       ...         ...                      ...
# 2496        2496  11690402    JC267219  2019-05-17T16:00:00.000
# 2497        2497  11690766    JC267550  2019-05-17T20:45:00.000
# 2498        2498  11691431    JC268231  2019-05-05T14:30:00.000
# 2499        2499  11691678    JC268692  2019-05-18T19:25:00.000
# 2500        2500  11692445    JC269546  2019-05-19T12:30:00.000
#
#                      block  iucr        primary_type  \
# 59    008XX N MICHIGAN AVE  1154  DECEPTIVE PRACTICE
# 162   008XX N MICHIGAN AVE  0890               THEFT
# 163   008XX N MICHIGAN AVE  0860               THEFT
# 164   008XX N MICHIGAN AVE  0460             BATTERY
# 165   008XX N MICHIGAN AVE  0890               THEFT
# ...                    ...   ...                 ...
# 2496  008XX N MICHIGAN AVE  0820               THEFT
# 2497  008XX N MICHIGAN AVE  0870               THEFT
# 2498  008XX N MICHIGAN AVE  0860               THEFT
# 2499  008XX N MICHIGAN AVE  501A       OTHER OFFENSE
# 2500  008XX N MICHIGAN AVE  0860               THEFT
#
#                                   description location_description  arrest  \
# 59    FINANCIAL IDENTITY THEFT $300 AND UNDER           RESTAURANT   False
# 162                             FROM BUILDING           RESTAURANT   False
# 163                              RETAIL THEFT   SMALL RETAIL STORE   False
# 164                                    SIMPLE               STREET   False
# 165                             FROM BUILDING           RESTAURANT   False
# ...                                       ...                  ...     ...
# 2496                           $500 AND UNDER     DEPARTMENT STORE   False
# 2497                           POCKET-PICKING             SIDEWALK   False
# 2498                             RETAIL THEFT   SMALL RETAIL STORE    True
# 2499                     ANIMAL ABUSE/NEGLECT               STREET   False
# 2500                             RETAIL THEFT     DEPARTMENT STORE    True
#
#       ...  ward  community_area  fbi_code  year               updated_on  \
# 59    ...     2               8        11  2019  2020-08-08T15:46:06.000
# 162   ...     2               8        06  2019  2019-12-30T15:56:10.000
# 163   ...     2               8        06  2019  2019-12-29T15:47:59.000
# 164   ...     2               8       08B  2019  2019-12-28T15:51:41.000
# 165   ...    42               8        06  2019  2019-12-27T15:47:52.000
# ...   ...   ...             ...       ...   ...                      ...
# 2496  ...     2               8        06  2019  2019-05-24T16:15:50.000
# 2497  ...     2               8        06  2019  2019-05-24T16:15:50.000
# 2498  ...     2               8        06  2019  2019-05-22T16:04:24.000
# 2499  ...    42               8        26  2019  2019-05-25T16:16:00.000
# 2500  ...     2               8        06  2019  2019-05-26T16:04:27.000
#
#      x_coordinate  y_coordinate   latitude  longitude  \
# 59      1177330.0     1906499.0  41.898768 -87.624116
# 162     1177330.0     1906499.0  41.898768 -87.624116
# 163     1177338.0     1906181.0  41.897895 -87.624097
# 164     1177338.0     1906181.0  41.897895 -87.624097
# 165     1177338.0     1906160.0  41.897838 -87.624097
# ...           ...           ...        ...        ...
# 2496    1177338.0     1906181.0  41.897895 -87.624097
# 2497    1177338.0     1906181.0  41.897895 -87.624097
# 2498    1177330.0     1906499.0  41.898768 -87.624116
# 2499    1177311.0     1905834.0  41.896944 -87.624206
# 2500    1177338.0     1906181.0  41.897895 -87.624097
#
#                                                location
# 59    {'latitude': '41.898767916', 'longitude': '-87...
# 162   {'latitude': '41.898767916', 'longitude': '-87...
# 163   {'latitude': '41.897895128', 'longitude': '-87...
# 164   {'latitude': '41.897895128', 'longitude': '-87...
# 165   {'latitude': '41.897837503', 'longitude': '-87...
# ...                                                 ...
# 2496  {'latitude': '41.897895128', 'longitude': '-87...
# 2497  {'latitude': '41.897895128', 'longitude': '-87...
# 2498  {'latitude': '41.898767916', 'longitude': '-87...
# 2499  {'latitude': '41.896943556', 'longitude': '-87...
# 2500  {'latitude': '41.897895128', 'longitude': '-87...
#
# [473 rows x 23 columns]

# %%
top_10_2019=crime_2019_df.groupby(["iucr","primary_type","description"]).count()["id"]
#top_10_2019_df=pd.DataFrame(top_10_2019.values)
#df1 = pd.DataFrame(data=top_10_2019.index, columns=['iucr'])
#df2 = pd.DataFrame(data=top_10_2019.values, columns=[''])
#top_10_2019_df = pd.merge(df1, df2, left_index=True, right_index=True)
top_10_2019
# Out:
# iucr  primary_type                description
# 0312  ROBBERY                     ARMED:KNIFE/CUTTING INSTRUMENT               1
# 0320  ROBBERY                     STRONGARM - NO WEAPON                        2
# 0330  ROBBERY                     AGGRAVATED                                   1
# 0430  BATTERY                     AGGRAVATED: OTHER DANG WEAPON                2
# 0454  BATTERY                     AGG PO HANDS NO/MIN INJURY                   1
# 0460  BATTERY                     SIMPLE                                      17
# 0470  PUBLIC PEACE VIOLATION      RECKLESS CONDUCT                             1
# 0483  BATTERY                     AGG PRO.EMP: OTHER DANG WEAPON               2
# 0486  BATTERY                     DOMESTIC BATTERY SIMPLE                      2
# 0495  BATTERY                     AGGRAVATED OF A SENIOR CITIZEN               1
# 0520  ASSAULT                     AGGRAVATED:KNIFE/CUTTING INSTR               2
# 0530  ASSAULT                     AGGRAVATED: OTHER DANG WEAPON                1
# 0552  ASSAULT                     AGGRAVATED PO:KNIFE/CUT INSTR                1
# 0560  ASSAULT                     SIMPLE                                       8
# 0584  STALKING                    VIOLATION OF STALKING NO CONTACT ORDER       1
# 0810  THEFT                       OVER $500                                   11
# 0820  THEFT                       $500 AND UNDER                              15
# 0850  THEFT                       ATTEMPT THEFT                                7
# 0860  THEFT                       RETAIL THEFT                               185
# 0870  THEFT                       POCKET-PICKING                              28
# 0880  THEFT                       PURSE-SNATCHING                              1
# 0890  THEFT                       FROM BUILDING                               53
# 0910  MOTOR VEHICLE THEFT         AUTOMOBILE                                   1
# 1121  DECEPTIVE PRACTICE          COUNTERFEITING DOCUMENT                      3
# 1130  DECEPTIVE PRACTICE          FRAUD OR CONFIDENCE GAME                     1
# 1150  DECEPTIVE PRACTICE          CREDIT CARD FRAUD                           83
# 1151  DECEPTIVE PRACTICE          ILLEGAL POSSESSION CASH CARD                 1
# 1152  DECEPTIVE PRACTICE          ILLEGAL USE CASH CARD                       11
# 1153  DECEPTIVE PRACTICE          FINANCIAL IDENTITY THEFT OVER $ 300          4
# 1154  DECEPTIVE PRACTICE          FINANCIAL IDENTITY THEFT $300 AND UNDER      4
# 1156  DECEPTIVE PRACTICE          ATTEMPT - FINANCIAL IDENTITY THEFT           2
# 1220  DECEPTIVE PRACTICE          THEFT OF LOST/MISLAID PROP                   1
# 1310  CRIMINAL DAMAGE             TO PROPERTY                                  2
# 1320  CRIMINAL DAMAGE             TO VEHICLE                                   2
# 1330  CRIMINAL TRESPASS           TO LAND                                      8
# 1345  CRIMINAL DAMAGE             TO CITY OF CHICAGO PROPERTY                  1
# 1725  OFFENSE INVOLVING CHILDREN  CONTRIBUTE CRIM DELINQUENCY JUVENILE         1
# 1780  OFFENSE INVOLVING CHILDREN  OTHER OFFENSE                                1
# 2820  OTHER OFFENSE               TELEPHONE THREAT                             1
# 2825  OTHER OFFENSE               HARASSMENT BY TELEPHONE                      1
# 4387  OTHER OFFENSE               VIOLATE ORDER OF PROTECTION                  1
# 501A  OTHER OFFENSE               ANIMAL ABUSE/NEGLECT                         1
# Name: id, dtype: int64
